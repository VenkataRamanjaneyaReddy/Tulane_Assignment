# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('Class-Subclass_1975-2010.csv')

# %%
df.head()
# Out:
#    Unnamed: 0   patent  prim class subclass        n
# 0           0  3858241     1     2      2.5  34753.0
# 1           1  3858242     0     2      427  34753.0
# 2           2  3858242     0     2      424  34753.0
# 3           3  3858242     1     2       10  34753.0
# 4           4  3858242     0     2      2.5  34753.0

# %%
df.isnull().sum()
# Out:
# Unnamed: 0    0
# patent        0
# prim          0
# class         0
# subclass      0
# n             0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17445405 entries, 0 to 17445404
# Data columns (total 6 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   Unnamed: 0  int64
#  1   patent      int64
#  2   prim        int64
#  3   class       object
#  4   subclass    object
#  5   n           float64
# dtypes: float64(1), int64(3), object(2)
# memory usage: 798.6+ MB

# %%
df['class'].unique().tolist()
# Out:
# ['2',
#  '69',
#  '128',
#  '623',
#  '606',
#  '137',
#  '4',
#  '239',
#  '5',
#  '312',
#  '297',
#  '81',
#  '7',
#  '564',
#  '8',
#  '558',
#  '114',
#  '470',
#  '12',
#  '14',
#  '15',
#  '434',
#  '403',
#  '294',
#  '16',
#  'D8',
#  '55',
#  '220',
#  '528',
#  '428',
#  '19',
#  '24',
#  '70',
#  '138',
#  '313',
#  '445',
#  '29',
#  '242',
#  '483',
#  '409',
#  '408',
#  '101',
#  '492',
#  '33',
#  '324',
#  '73',
#  '416',
#  '165',
#  '60',
#  '365',
#  '148',
#  '228',
#  '438',
#  '430',
#  '257',
#  '381',
#  '361',
#  '307',
#  '369',
#  '310',
#  '419',
#  '140',
#  '336',
#  '156',
#  '30',
#  '52',
#  'D7',
#  '164',
#  '433',
#  'D10',
#  '384',
#  '74',
#  '219',
#  '34',
#  '261',
#  '96',
#  'D18',
#  '273',
#  '36',
#  '37',
#  '40',
#  '345',
#  '42',
#  '43',
#  '514',
#  '424',
#  '446',
#  '244',
#  '47',
#  '454',
#  '49',
#  '160',
#  '451',
#  '209',
#  '404',
#  '53',
#  '464',
#  'D25',
#  '65',
#  '524',
#  '601',
#  '523',
#  '221',
#  '56',
# ...

# %%
df['class'] = pd.to_numeric(df['class'], errors='coerce').fillna(0, downcast='infer')

# %%
df['class'].unique()
# Out:
# array([  2,  69, 128, 623, 606, 137,   4, 239,   5, 312, 297,  81,   7,
#        564,   8, 558, 114, 470,  12,  14,  15, 434, 403, 294,  16,   0,
#         55, 220, 528, 428,  19,  24,  70, 138, 313, 445,  29, 242, 483,
#        409, 408, 101, 492,  33, 324,  73, 416, 165,  60, 365, 148, 228,
#        438, 430, 257, 381, 361, 307, 369, 310, 419, 140, 336, 156,  30,
#         52, 164, 433, 384,  74, 219,  34, 261,  96, 273,  36,  37,  40,
#        345,  42,  43, 514, 424, 446, 244,  47, 454,  49, 160, 451, 209,
#        404,  53, 464,  65, 524, 601, 523, 221,  56,  57, 264, 368, 968,
#        429, 123, 149, 102,  89,  91, 299, 405, 166, 423,  23, 256, 175,
#         62,  66, 700,  68,  72, 425,  83, 100, 374, 422, 173, 327, 476,
#        198, 474, 184, 277, 192, 477, 475,  76,  79, 188, 269, 493,  84,
#        411, 984, 279,  82,  92, 271, 426,  99, 210, 248, 141, 241, 118,
#        400, 427, 346, 360, 104, 280, 414, 105, 505, 180, 206, 108, 211,
# ...

# %%
int(df['class'].mean())
# Out:
# 351

# %%
df['class'] = df['class'].replace(0, 351)

# %%
df['subclass'] = pd.to_numeric(df['subclass'], errors='coerce').fillna(0, downcast='infer')

# %%
df['subclass'].unique()
# Out:
# array([2.50000e+00, 4.27000e+02, 4.24000e+02, ..., 3.57440e+04,
#        9.99106e+05, 9.99020e+04])

# %%
df['subclass'].mean()
# Out:
# 891.8901370225573

# %%
df['subclass'] = df['subclass'].replace(0, 891.89)

# %%
df['subclass'].unique().tolist()
# Out:
# [2.5,
#  427.0,
#  424.0,
#  10.0,
#  52.0,
#  21.5,
#  338.0,
#  898.0,
#  15.11,
#  187.0,
#  2.34,
#  533.27,
#  533.23,
#  533.19,
#  533.25,
#  7.0,
#  345.0,
#  323.0,
#  317.0,
#  324.0,
#  393.0,
#  111.3,
#  111.5,
#  111.4,
#  310.0,
#  601.0,
#  615.0,
#  282.0,
#  569.0,
#  2.1,
#  317.2,
#  279.0,
#  9.1,
#  8.0,
#  45.0,
#  59.1,
#  225.0,
#  496.0,
#  636.0,
#  437.0,
#  148.0,
#  165.0,
#  142.0,
#  129.0,
#  315.0,
#  86.0,
#  922.0,
#  662.0,
#  403.0,
#  694.0,
#  659.0,
#  344.0,
#  205.0,
#  63.0,
#  21.0,
#  19.0,
#  891.89,
#  71.3,
#  52.1,
#  319.0,
#  417.0,
#  103.0,
#  340.1,
#  77.0,
#  177.0,
#  192.0,
#  146.0,
#  19.1,
#  144.1,
#  236.04,
#  16.0,
#  389.0,
#  29.0,
#  105.0,
#  39.0,
#  410.0,
#  357.0,
#  322.0,
#  405.0,
#  236.0,
#  245.0,
#  178.0,
#  182.0,
#  312.0,
#  98.0,
#  99.0,
#  260.0,
#  293.0,
#  910.0,
#  200.0,
#  276.0,
#  704.1,
#  57.1,
#  108.0,
#  110.0,
#  706.8,
#  708.9,
#  601.7,
#  598.1,
#  586.1,
#  168.0,
#  388.0,
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0    0
# patent        0
# prim          0
# class         0
# subclass      0
# n             0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17445405 entries, 0 to 17445404
# Data columns (total 6 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   Unnamed: 0  int64
#  1   patent      int64
#  2   prim        int64
#  3   class       int64
#  4   subclass    float64
#  5   n           float64
# dtypes: float64(2), int64(4)
# memory usage: 798.6 MB

# %%
df.drop('Unnamed: 0', axis=1, inplace=True)

# %%
df.head()
# Out:
#     patent  prim  class  subclass        n
# 0  3858241     1      2       2.5  34753.0
# 1  3858242     0      2     427.0  34753.0
# 2  3858242     0      2     424.0  34753.0
# 3  3858242     1      2      10.0  34753.0
# 4  3858242     0      2       2.5  34753.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17445405 entries, 0 to 17445404
# Data columns (total 5 columns):
#  #   Column    Dtype
# ---  ------    -----
#  0   patent    int64
#  1   prim      int64
#  2   class     int64
#  3   subclass  float64
#  4   n         float64
# dtypes: float64(2), int64(3)
# memory usage: 665.5 MB

# %%
# sns.heatmap(df.isnull(), cbar=False)

# %%
df.to_csv('Class-Subclass.csv')
